# %%
import os

limit = 3

def ngrams(lines):
    global limit
    ngrams = []
    for i in range(1, limit+1):
        ndict = {}
        for line in lines:
            nline = ['<START>']*i + line + ['<END>']*i
            for x in range(len(nline)- i) :
                key = '_'.join(nline[x:x+i])
                if key in ndict.keys():
                    ndict[key] += 1
                else:
                    ndict[key] = 1
        ngrams += [ndict]
        print ("ngrams",ngrams)
    return ngrams

def cleanLines(lines):
    for i in range(len(lines)):
        lines[i] = lines[i][:-1].split()
        for x in range(len(lines[i])):
            lines[i][x] = lines[i][x].lower()
    return lines

def score(uinput, tngramsdict):
    global limit
    scores = []
    uinput = [uinput.lower().split()]
    cur_ngramsdict = ngrams(uinput)
    for key in tngramsdict:
        ngramsdict = tngramsdict[key]
        fscore = 0.0
        for i in range(len(cur_ngramsdict)):
            cur_dict = cur_ngramsdict[i]
            ansdict = ngramsdict[i]

            precision = 0
            for i in cur_dict.keys():
                if i in ansdict.keys():
                    precision+=1

            recall = 0
            for i in ansdict.keys():
                if i in cur_dict.keys():
                    recall+=1

            fscore += 1.0/float((len(ansdict.keys())/float(precision) + len(ansdict.keys())/float(recall)))
        scores+= [(key,fscore)]
    return scores

def init():
    ngramsdict = {}
    path = './intents/'

    for fil in os.listdir(path):
        if fil.endswith('.dat'):
            with open(path + fil) as f:
                lines = f.readlines()
                lines = cleanLines(lines)
                ngramsdict[''.join(fil.split('.')[:-1])] = ngrams(lines)
    return ngramsdict

def ngrammatch(uinput):
    ngramsdict = init()
    scores = score(uinput, ngramsdict)
    #print scores
    return scores

# %%
ngrammatch("want a laptop")
# Out:
# ngrams [{'order': 2, 'me': 14, 'size': 13, 'this': 22, 'a': 50, 'personal': 1, 'hard': 6, 'resoultion': 2, '$harddisksize': 17, 'best': 3, 'laptop?': 3, 'mentioned': 1, 'looking': 4, 'type': 10, 'need': 16, 'as': 11, 'good': 2, 'capacity': 9, 'from': 1, 'define': 1, 'get': 11, '$screensize': 22, 'screen': 13, 'buying': 1, 'ram': 2, 'like': 1, 'should': 2, 'finding': 1, 'system': 14, '$brand': 36, 'fit': 1, 'stock?': 1, 'storage': 7, 'and': 10, 'add': 1, 'choose': 5, 'mention': 1, 'for': 21, 'my': 22, 'resolution': 8, 'would': 10, 'memory': 9, 'is': 1, 'i': 65, 'plese': 2, '$ram': 22, 'configuration': 2, '$harddrive': 1, 'operating': 19, 'laptop': 58, 'select': 12, '$harddisktype': 12, 'model': 1, 'provide': 3, 'drive': 6, 'help': 8, 'recommend': 2, 'please': 24, 'device': 2, '<START>': 104, '$os': 23, 'gaming': 2, 'purchase': 2, 'can': 1, 'preferred': 2, 'devise': 1, 'with': 30, 'the': 31, 'am': 5, 'suggest': 1, 'take': 4, 'interested': 1, 'find': 2, 'in': 10, 'to': 30, 'preffered': 10, 'want': 40, 'buy': 20, 'of': 1, 'use': 1}]
# ngrams [{'order': 2, 'me': 14, 'size': 13, 'this': 22, 'a': 50, 'personal': 1, 'hard': 6, 'resoultion': 2, '$harddisksize': 17, 'best': 3, 'laptop?': 3, 'mentioned': 1, 'looking': 4, 'type': 10, 'need': 16, 'as': 11, 'good': 2, 'capacity': 9, 'from': 1, 'define': 1, 'get': 11, '$screensize': 22, 'screen': 13, 'buying': 1, 'ram': 2, 'like': 1, 'should': 2, 'finding': 1, 'system': 14, '$brand': 36, 'fit': 1, 'stock?': 1, 'storage': 7, 'and': 10, 'add': 1, 'choose': 5, 'mention': 1, 'for': 21, 'my': 22, 'resolution': 8, 'would': 10, 'memory': 9, 'is': 1, 'i': 65, 'plese': 2, '$ram': 22, 'configuration': 2, '$harddrive': 1, 'operating': 19, 'laptop': 58, 'select': 12, '$harddisktype': 12, 'model': 1, 'provide': 3, 'drive': 6, 'help': 8, 'recommend': 2, 'please': 24, 'device': 2, '<START>': 104, '$os': 23, 'gaming': 2, 'purchase': 2, 'can': 1, 'preferred': 2, 'devise': 1, 'with': 30, 'the': 31, 'am': 5, 'suggest': 1, 'take': 4, 'interested': 1, 'find': 2, 'in': 10, 'to': 30, 'preffered': 10, 'want': 40, 'buy': 20, 'of': 1, 'use': 1}, {'preffered_operating': 2, 'memory_and': 1, '$harddisksize_hard': 5, 'to_choose': 1, 'am_looking': 4, '<START>_need': 2, '$harddisksize_capacity': 5, 'resolution_for': 1, 'a_$screensize': 1, '$ram_in': 1, 'fit_$harddisksize': 1, 'with_$harddisksize': 4, 'to_buy': 18, 'in_size': 1, 'choose_my': 1, 'should_i': 2, 'a_gaming': 2, '$harddisktype_storage': 4, 'provide_this': 1, 'screen_resoultion': 2, '$os_<END>': 5, 'in_buying': 1, 'and_ram': 2, 'and_screen': 1, 'laptop_$brand': 1, 'this_my': 1, 'configuration_<END>': 2, 'please_select': 10, 'please_define': 1, 'memory_capacity': 1, '$harddisktype_as': 1, 'need_this': 1, 'define_my': 1, '$ram_configuration': 1, 'drive_and': 1, 'to_take': 4, 'as_$os': 3, 'my_preffered': 10, 'in_$os': 1, 'storage_type': 7, 'would_recommend': 2, 'this_laptop?': 1, 'provide_a': 1, 'laptop_from': 1, 'for_personal': 1, 'finding_the': 1, 'select_$screensize': 1, 'want_the': 7, '$harddisktype_<END>': 3, 'operating_laptop': 1, '$brand_laptop?': 1, 'get_me': 6, 'get_the': 2, '$os_for': 1, 'interested_in': 1, 'as_$harddisktype': 2, 'please_choose': 3, 'this_$brand': 1, 'plese_get': 1, 'screen_resolution': 8, 'mention_the': 1, '<START>_add': 1, 'to_my': 1, 'please_mentioned': 1, 'want_to': 24, 'best_fit': 1, 'preffered_$harddisktype': 1, 'operating_as': 3, 'laptop_with': 27, 'suggest_a': 1, 'with_$os': 3, '<START>_provide': 1, 'hard_drive': 6, 'a_$brand': 25, 'and_$screensize': 2, '$screensize_as': 2, 'the_choose': 1, 'me_order': 1, 'and_operating': 1, 'my_$os': 1, 'my_order': 1, '$brand_for': 2, 'me_to': 4, 'recommend_the': 1, 'order_a': 1, 'size_$ram': 2, 'get_$harddisksize': 1, 'a_best': 2, 'preffered_$brand': 1, 'this_$ram': 1, '<START>_i': 62, 'resolution_$screensize': 1, 'can_i': 1, 'the_system': 1, 'is_the': 1, '$screensize_<END>': 7, 'the_best': 1, 'am_interested': 1, '$harddisktype_type': 2, '$brand_laptop': 24, 'i_need': 6, 'size_for': 2, 'this_device': 2, '$brand_and': 1, 'add_a': 1, '<START>_please': 24, 'looking_this': 1, 'this_$os': 2, '<START>_can': 1, 'this_$harddisksize': 1, 'want_$ram': 1, 'order_<END>': 1, 'want_my': 1, 'use_<END>': 1, '$os_with': 1, 'need_the': 3, 'laptop_<END>': 22, 'laptop_in': 6, '$ram_system': 5, 'the_$ram': 4, 'please_provide': 2, '<START>_is': 1, 'would_need': 8, 'the_laptop?': 1, '$screensize_configuration': 1, 'and_$os': 1, 'the_storage': 3, 'help_me': 7, 'select_this': 1, '$harddrive_and': 1, 'the_$harddisksize': 4, 'want_$os': 1, '<START>_plese': 2, 'please_get': 5, 'resolution_<END>': 6, 'choose_select': 1, 'select_the': 2, 'take_my': 1, 'i_want': 40, 'as_$ram': 1, 'get_a': 2, 'type_and': 1, 'capacity_for': 3, 'this_$screensize': 1, 'purchase_a': 2, 'gaming_laptop': 2, 'my_operating': 1, '$ram_capacity': 3, 'to_get': 2, 'i_get': 3, 'with_$ram': 7, 'a_$os': 3, 'please_mention': 1, 'choose_this': 1, 'i_am': 5, 'need_$harddisksize': 1, 'size_and': 2, 'with_$harddisktype': 2, 'find_a': 2, 'select_my': 8, '<START>_<START>': 104, 'the_$brand':  ...
# ngrams [{'order': 2, 'me': 14, 'size': 13, 'this': 22, 'a': 50, 'personal': 1, 'hard': 6, 'resoultion': 2, '$harddisksize': 17, 'best': 3, 'laptop?': 3, 'mentioned': 1, 'looking': 4, 'type': 10, 'need': 16, 'as': 11, 'good': 2, 'capacity': 9, 'from': 1, 'define': 1, 'get': 11, '$screensize': 22, 'screen': 13, 'buying': 1, 'ram': 2, 'like': 1, 'should': 2, 'finding': 1, 'system': 14, '$brand': 36, 'fit': 1, 'stock?': 1, 'storage': 7, 'and': 10, 'add': 1, 'choose': 5, 'mention': 1, 'for': 21, 'my': 22, 'resolution': 8, 'would': 10, 'memory': 9, 'is': 1, 'i': 65, 'plese': 2, '$ram': 22, 'configuration': 2, '$harddrive': 1, 'operating': 19, 'laptop': 58, 'select': 12, '$harddisktype': 12, 'model': 1, 'provide': 3, 'drive': 6, 'help': 8, 'recommend': 2, 'please': 24, 'device': 2, '<START>': 104, '$os': 23, 'gaming': 2, 'purchase': 2, 'can': 1, 'preferred': 2, 'devise': 1, 'with': 30, 'the': 31, 'am': 5, 'suggest': 1, 'take': 4, 'interested': 1, 'find': 2, 'in': 10, 'to': 30, 'preffered': 10, 'want': 40, 'buy': 20, 'of': 1, 'use': 1}, {'preffered_operating': 2, 'memory_and': 1, '$harddisksize_hard': 5, 'to_choose': 1, 'am_looking': 4, '<START>_need': 2, '$harddisksize_capacity': 5, 'resolution_for': 1, 'a_$screensize': 1, '$ram_in': 1, 'fit_$harddisksize': 1, 'with_$harddisksize': 4, 'to_buy': 18, 'in_size': 1, 'choose_my': 1, 'should_i': 2, 'a_gaming': 2, '$harddisktype_storage': 4, 'provide_this': 1, 'screen_resoultion': 2, '$os_<END>': 5, 'in_buying': 1, 'and_ram': 2, 'and_screen': 1, 'laptop_$brand': 1, 'this_my': 1, 'configuration_<END>': 2, 'please_select': 10, 'please_define': 1, 'memory_capacity': 1, '$harddisktype_as': 1, 'need_this': 1, 'define_my': 1, '$ram_configuration': 1, 'drive_and': 1, 'to_take': 4, 'as_$os': 3, 'my_preffered': 10, 'in_$os': 1, 'storage_type': 7, 'would_recommend': 2, 'this_laptop?': 1, 'provide_a': 1, 'laptop_from': 1, 'for_personal': 1, 'finding_the': 1, 'select_$screensize': 1, 'want_the': 7, '$harddisktype_<END>': 3, 'operating_laptop': 1, '$brand_laptop?': 1, 'get_me': 6, 'get_the': 2, '$os_for': 1, 'interested_in': 1, 'as_$harddisktype': 2, 'please_choose': 3, 'this_$brand': 1, 'plese_get': 1, 'screen_resolution': 8, 'mention_the': 1, '<START>_add': 1, 'to_my': 1, 'please_mentioned': 1, 'want_to': 24, 'best_fit': 1, 'preffered_$harddisktype': 1, 'operating_as': 3, 'laptop_with': 27, 'suggest_a': 1, 'with_$os': 3, '<START>_provide': 1, 'hard_drive': 6, 'a_$brand': 25, 'and_$screensize': 2, '$screensize_as': 2, 'the_choose': 1, 'me_order': 1, 'and_operating': 1, 'my_$os': 1, 'my_order': 1, '$brand_for': 2, 'me_to': 4, 'recommend_the': 1, 'order_a': 1, 'size_$ram': 2, 'get_$harddisksize': 1, 'a_best': 2, 'preffered_$brand': 1, 'this_$ram': 1, '<START>_i': 62, 'resolution_$screensize': 1, 'can_i': 1, 'the_system': 1, 'is_the': 1, '$screensize_<END>': 7, 'the_best': 1, 'am_interested': 1, '$harddisktype_type': 2, '$brand_laptop': 24, 'i_need': 6, 'size_for': 2, 'this_device': 2, '$brand_and': 1, 'add_a': 1, '<START>_please': 24, 'looking_this': 1, 'this_$os': 2, '<START>_can': 1, 'this_$harddisksize': 1, 'want_$ram': 1, 'order_<END>': 1, 'want_my': 1, 'use_<END>': 1, '$os_with': 1, 'need_the': 3, 'laptop_<END>': 22, 'laptop_in': 6, '$ram_system': 5, 'the_$ram': 4, 'please_provide': 2, '<START>_is': 1, 'would_need': 8, 'the_laptop?': 1, '$screensize_configuration': 1, 'and_$os': 1, 'the_storage': 3, 'help_me': 7, 'select_this': 1, '$harddrive_and': 1, 'the_$harddisksize': 4, 'want_$os': 1, '<START>_plese': 2, 'please_get': 5, 'resolution_<END>': 6, 'choose_select': 1, 'select_the': 2, 'take_my': 1, 'i_want': 40, 'as_$ram': 1, 'get_a': 2, 'type_and': 1, 'capacity_for': 3, 'this_$screensize': 1, 'purchase_a': 2, 'gaming_laptop': 2, 'my_operating': 1, '$ram_capacity': 3, 'to_get': 2, 'i_get': 3, 'with_$ram': 7, 'a_$os': 3, 'please_mention': 1, 'choose_this': 1, 'i_am': 5, 'need_$harddisksize': 1, 'size_and': 2, 'with_$harddisktype': 2, 'find_a': 2, 'select_my': 8, '<START>_<START>': 104, 'the_$brand':  ...
# ngrams [{'with': 4, 'i': 27, 'a': 74, 'go': 2, 'type': 7, 'provide': 4, '$cuisine': 40, 'best': 15, 'reserve': 5, 'good': 2, 'please': 9, '<START>': 100, 'book': 79, 'we': 3, 'pricing': 18, 'table': 5, '$costtype': 49, 'the': 22, 'am': 6, 'for': 7, 'restaurant': 100, 'looking': 6, 'in': 48, 'me': 6, 'to': 28, 'give': 2, 'famous': 20, 'want': 27, '$location': 49, 'pricin': 1, 'at': 1, 'details': 2, 'of': 16}]
# ngrams [{'with': 4, 'i': 27, 'a': 74, 'go': 2, 'type': 7, 'provide': 4, '$cuisine': 40, 'best': 15, 'reserve': 5, 'good': 2, 'please': 9, '<START>': 100, 'book': 79, 'we': 3, 'pricing': 18, 'table': 5, '$costtype': 49, 'the': 22, 'am': 6, 'for': 7, 'restaurant': 100, 'looking': 6, 'in': 48, 'me': 6, 'to': 28, 'give': 2, 'famous': 20, 'want': 27, '$location': 49, 'pricin': 1, 'at': 1, 'details': 2, 'of': 16}, {'pricin_<END>': 1, 'of_$cuisine': 6, 'in_a': 4, 'am_looking': 6, 'of_$costtype': 8, 'details_of': 2, 'want_to': 27, '<START>_book': 32, 'book_$costtype': 2, 'good_restaurant': 2, 'to_a': 1, 'a_good': 2, '<START>_provide': 4, 'restaurant_book': 3, 'pricing_<END>': 7, '<START>_give': 2, '$location_book': 10, 'book_the': 22, 'the_famous': 7, 'famous_$costtype': 5, '<START>_$location': 4, '<START>_i': 27, 'type_restaurant': 7, '<START>_we': 3, 'for_$cuisine': 1, 'we_want': 3, '<START>_<START>': 100, '<START>_a': 1, '<START>_want': 3, 'a_table': 5, 'restaurant_of': 14, 'restaurant_<END>': 47, '$costtype_pricin': 1, 'restaurant_with': 4, '<START>_restaurant': 1, 'pricing_restaurant': 7, 'restaurant_in': 32, '$costtype_pricing': 18, 'reserve_a': 5, '<START>_please': 7, 'pricing_in': 4, 'at_$location': 1, '<START>_reserve': 4, 'to_go': 2, 'famous_$cuisine': 8, 'please_book': 9, '$location_reserve': 1, 'the_best': 15, 'a_restaurant': 16, '$cuisine_restaurant': 34, '$cuisine_<END>': 6, 'in_$location': 44, 'give_me': 2, '<START>_in': 8, 'looking_for': 6, 'famous_restaurant': 7, 'a_$costtype': 20, 'me_a': 4, 'table_for': 1, 'table_in': 4, '<START>_at': 1, 'to_book': 25, '<START>_$costtype': 1, 'a_famous': 11, 'provide_me': 4, 'go_a': 1, 'with_$costtype': 4, '$costtype_restaurant': 23, '$costtype_type': 7, 'of_famous': 2, 'best_$cuisine': 3, 'best_restaurant': 3, 'for_a': 6, 'go_to': 1, 'book_<END>': 3, 'i_am': 6, '$location_please': 2, 'a_$cuisine': 20, '$location_<END>': 36, 'best_$costtype': 9, 'book_a': 52, 'i_want': 21, 'me_details': 2, '<START>_$cuisine': 2}]
# ngrams [{'with': 4, 'i': 27, 'a': 74, 'go': 2, 'type': 7, 'provide': 4, '$cuisine': 40, 'best': 15, 'reserve': 5, 'good': 2, 'please': 9, '<START>': 100, 'book': 79, 'we': 3, 'pricing': 18, 'table': 5, '$costtype': 49, 'the': 22, 'am': 6, 'for': 7, 'restaurant': 100, 'looking': 6, 'in': 48, 'me': 6, 'to': 28, 'give': 2, 'famous': 20, 'want': 27, '$location': 49, 'pricin': 1, 'at': 1, 'details': 2, 'of': 16}, {'pricin_<END>': 1, 'of_$cuisine': 6, 'in_a': 4, 'am_looking': 6, 'of_$costtype': 8, 'details_of': 2, 'want_to': 27, '<START>_book': 32, 'book_$costtype': 2, 'good_restaurant': 2, 'to_a': 1, 'a_good': 2, '<START>_provide': 4, 'restaurant_book': 3, 'pricing_<END>': 7, '<START>_give': 2, '$location_book': 10, 'book_the': 22, 'the_famous': 7, 'famous_$costtype': 5, '<START>_$location': 4, '<START>_i': 27, 'type_restaurant': 7, '<START>_we': 3, 'for_$cuisine': 1, 'we_want': 3, '<START>_<START>': 100, '<START>_a': 1, '<START>_want': 3, 'a_table': 5, 'restaurant_of': 14, 'restaurant_<END>': 47, '$costtype_pricin': 1, 'restaurant_with': 4, '<START>_restaurant': 1, 'pricing_restaurant': 7, 'restaurant_in': 32, '$costtype_pricing': 18, 'reserve_a': 5, '<START>_please': 7, 'pricing_in': 4, 'at_$location': 1, '<START>_reserve': 4, 'to_go': 2, 'famous_$cuisine': 8, 'please_book': 9, '$location_reserve': 1, 'the_best': 15, 'a_restaurant': 16, '$cuisine_restaurant': 34, '$cuisine_<END>': 6, 'in_$location': 44, 'give_me': 2, '<START>_in': 8, 'looking_for': 6, 'famous_restaurant': 7, 'a_$costtype': 20, 'me_a': 4, 'table_for': 1, 'table_in': 4, '<START>_at': 1, 'to_book': 25, '<START>_$costtype': 1, 'a_famous': 11, 'provide_me': 4, 'go_a': 1, 'with_$costtype': 4, '$costtype_restaurant': 23, '$costtype_type': 7, 'of_famous': 2, 'best_$cuisine': 3, 'best_restaurant': 3, 'for_a': 6, 'go_to': 1, 'book_<END>': 3, 'i_am': 6, '$location_please': 2, 'a_$cuisine': 20, '$location_<END>': 36, 'best_$costtype': 9, 'book_a': 52, 'i_want': 21, 'me_details': 2, '<START>_$cuisine': 2}, {'<START>_provide_me': 4, 'details_of_famous': 2, 'best_$cuisine_restaurant': 3, 'pricing_<END>_<END>': 7, '$cuisine_<END>_<END>': 6, 'the_best_$costtype': 9, 'famous_$costtype_restaurant': 3, 'give_me_details': 2, '<START>_<START>_please': 7, '<START>_i_want': 21, 'best_$costtype_restaurant': 5, 'of_famous_restaurant': 2, '<START>_in_$location': 8, '$cuisine_restaurant_<END>': 13, 'good_restaurant_in': 1, 'good_restaurant_<END>': 1, 'famous_$costtype_type': 1, 'for_$cuisine_restaurant': 1, 'book_a_famous': 10, 'with_$costtype_pricing': 4, 'best_$costtype_type': 2, 'of_$costtype_pricing': 7, 'we_want_to': 3, '$cuisine_restaurant_book': 2, 'in_a_$costtype': 1, 'book_a_restaurant': 13, 'to_go_to': 1, 'pricin_<END>_<END>': 1, '<START>_i_am': 6, 'a_famous_$costtype': 2, '<START>_<START>_at': 1, '<START>_<START>_book': 32, '<START>_<START>_we': 3, 'a_restaurant_in': 4, 'for_a_$costtype': 1, 'am_looking_for': 6, 'to_book_a': 19, 'a_$cuisine_restaurant': 20, 'in_a_restaurant': 1, 'in_$location_<END>': 36, 'restaurant_<END>_<END>': 47, 'table_for_$cuisine': 1, 'me_details_of': 2, 'a_famous_$cuisine': 5, '<START>_book_a': 15, 'me_a_good': 2, 'of_$cuisine_<END>': 6, 'the_famous_restaurant': 1, 'type_restaurant_<END>': 2, '$costtype_restaurant_<END>': 13, '<START>_$location_book': 4, 'go_to_a': 1, 'the_best_$cuisine': 3, '$costtype_pricing_<END>': 7, '<START>_please_book': 7, '$location_please_book': 2, '<START>_a_$cuisine': 1, 'for_a_famous': 1, 'the_famous_$costtype': 3, '$cuisine_restaurant_with': 4, '<START>_<START>_reserve': 4, 'for_a_$cuisine': 3, 'book_$costtype_restaurant': 2, '$costtype_pricin_<END>': 1, 'to_go_a': 1, 'famous_$costtype_pricing': 1, '$costtype_type_restaurant': 7, 'in_a_$cuisine': 2, 'pricing_restaurant_in': 5, 'restaurant_in_$location': 32, 'book_the_famous': 7, 'pricing_restaurant_<END>': 2, 'for_a_restaurant': 1, '<START>_<START>_give': 2, '<START>_<START>_a': 1, 'restaurant_with_$costtype': 4, 'book_<END>_<END>': 3, 'at_$location_book': 1, '<START>_give_me ...
# ngrams [{'<START>': 1, 'laptop': 1, 'want': 1, 'a': 1}]
# ngrams [{'<START>': 1, 'laptop': 1, 'want': 1, 'a': 1}, {'laptop_<END>': 1, '<START>_<START>': 1, '<START>_want': 1, 'want_a': 1, 'a_laptop': 1}]
# ngrams [{'<START>': 1, 'laptop': 1, 'want': 1, 'a': 1}, {'laptop_<END>': 1, '<START>_<START>': 1, '<START>_want': 1, 'want_a': 1, 'a_laptop': 1}, {'a_laptop_<END>': 1, '<START>_want_a': 1, '<START>_<START>_<START>': 1, '<START>_<START>_want': 1, 'want_a_laptop': 1, 'laptop_<END>_<END>': 1}]
# [('BuyLaptop', 0.0354944011316946), ('FindRestaurant', 0.06398182391559876)]
